# %% [markdown]
# ![library.png](attachment:library.png)

# %% [markdown]
# ## 1) `library` ชุดคำสั่งสำเร็จรูป

# %% [markdown]
# `library` เป็นชุดคำสั่งที่สร้างขึ้นโดย community เพื่อใช้งานกับงานที่เฉพาะเจาะจง การที่ python ได้รับความนิยมทำให้ `library` หรือเครื่องมือเหล่านี้มีความหลากหลายมากๆ เรียกว่าอยากใช้งานอะไร ถ้านึกออก สามารถหาเครื่องมือใช้ได้เลย

# %% [markdown]
# ## 2) การลง `library`

# %% [markdown]
# ใช้คำสั่ง `!` `pip` `install` ตามด้วย `ชื่อ library` เนื่องจาก `library` เป็นการสร้างด้วยผู้ใช้งานไม่ได้ติดมากับ python ตั้งแต่แรก

# %%
! pip install pandas

# %% [markdown]
# ## 3) `import` `library` ขึ้นมาบน Jupyter Notebook

# %% [markdown]
# ใช้คำสั่ง `import` ตามด้วย `ชื่อ library` เพื่อเรียกใช้ `library` ที่ติดตั้งแล้ว เมื่อติดตั้งไปแล้วไม่ต้องติดตั้งอีก แต่ต้อง `import` ทุกครั้งที่เปิด Jupyter Notebook ใหม่ทุกครั้ง

# %%
import pandas

# %% [markdown]
# ## 4) `import` `as` ตั้งชื่อเล่นให้ `library` คล้ายกับการสร้างตัวแปร

# %% [markdown]
# ใช้คำสั่ง `import` ตามด้วย `as` เป็นเหมือนการสร้างตัวแปรที่เก็บ `library` ไว้เพื่อใช้งาน ให้เรียกใช้ง่ายๆ

# %%
import pandas as pd

# %% [markdown]
# ## 5) ใช้งาน `function` ใน `library` ผ่าน `.`

# %% [markdown]
# คำสั่ง `.Series()` ใช้สร้าง `object` ประเภท `series`

# %%
pd.Series()
# Out:
# <ipython-input-4-fa15c544da3b>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   pd.Series()
# Series([], dtype: float64)

# %% [markdown]
# ### ติดต่อเราได้ที่
#
# Facebook: www.facebook.com/ubpc.python
#
# Website : www.ubpcpython.com
#
# Youtbe  : www.youtube.com/channel/UCqJqoqQJqhKNRPgaCtkON1w
